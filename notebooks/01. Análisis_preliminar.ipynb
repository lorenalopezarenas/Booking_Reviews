# %% [markdown]
# ----
# # **<span style="color:DarkSlateBlue">PROYECTO BOOKING_REVIEWS</span>**
# # **<span style="color:DarkSlateBlue">Análisis preliminar</span>**
# ----

# %% [markdown]
# ---
# ---
# ## <span style="color:gray">**1. Importación de librerías**</span> 📂

# %%
# Tratamiento de datos
import numpy as np
import pandas as pd 

# Configuración de ruta
import sys
sys.path.append('../')

# Importación de funciones personalizadas
from src.soporte1_preliminar import eda_preliminar

# %% [markdown]
# ---
# ---
# ## <span style="color:gray">**2. Carga de datos**</span> 📥

# %%
booking_raw = pd.read_csv("../data/raw/hotel_booking.csv")

reviews_raw = pd.read_csv("../data/raw/hotel_reviews.csv")

# %%
# Configuración para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ----
# # <span style="color:DarkSlateBlue">**Desarrollo del proyecto - 1**</span>
# ----

# %% [markdown]
# ---
# ---
# ## <span style="color:gray">**Exploración inicial de los datasets**</span> 🔎
#
# Antes de comenzar el análisis exploratorio de datos (EDA), es importante realizar una inspección general de los datasets. Este primer contacto con los datos nos permite entender su estructura, el tipo de variables que contienen y detectar posibles problemas como valores faltantes o formatos incorrectos.
#
# Para ello utilizamos varias funciones de Pandas que nos ayudan a obtener una visión rápida y completa del conjunto de datos.
#
# ---

# %% [markdown]
# ## `booking_raw`

# %%
# Llamamos a la función eda_preliminar guardada en el archivo de sorporte
eda_preliminar(booking_raw)
# Out:
# 👀 Visualización de las primeras y últimas filas
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# 1                        0                     0       2       0.0       0
# 2                        0                     1       1       0.0       0
#
#   meal country market_segment distribution_channel  is_repeated_guest  \
# 0   BB     PRT         Direct               Direct                  0
# 1   BB     PRT         Direct               Direct                  0
# 2   BB     GBR         Direct               Direct                  0
#
#    previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 0                       0                               0                  C
# 1                       0                               0                  C
# 2                       0                               0                  A
#
#   assigned_room_type  booking_changes deposit_type  agent  company  \
# 0                  C                3   No Deposit    NaN      NaN
# 1                  C                4   No Deposit    NaN      NaN
# 2                  C                0   No Deposit    NaN      NaN
#
#    days_in_waiting_list customer_type   adr  required_car_parking_spaces  \
# 0                     0     Transient   0.0                            0
# 1                     0     Transient   0.0                            0
# 2                     0     Transient  75.0                            0
#
#    total_of_special_requests reservation_status reservation_status_date  \
# 0                          0          Check-Out              2015-07-01
# 1                          0          Check-Out              2015-07-01
# 2                          0          Check-Out              2015-07-02
#
#              name                        email  phone-number       credit_card
# 0   Ernest Barnes  Ernest.Barnes31@outlook.com  669-792-1661  ************4322
# 1    Andrea Baker       Andrea_Baker94@aol.com  858-637-6955  ************9157
# 2  Rebecca Parker   Rebecca_Parker@comcast.net  652-885-2745  ************3734
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119387                         31                        2
# 119388                         31                        2
# 119389                         29                        2
#
#         stays_in_week_nights  adults  children  babies meal country  \
# 119387                     5       2       0.0       0   BB     DEU
# 119388                     5       2       0.0       0   BB     GBR
# 119389                     7       2       0.0       0   HB     DEU
#
#        market_segment distribution_channel  is_repeated_guest  \
# 119387      Online TA                TA/TO                  0
# 119388      Online TA                TA/TO                  0
# 119389      Online TA                TA/TO                  0
#
#         previous_cancellations  previous_bookings_not_canceled  \
# 119387                       0                               0
# 119388                       0                               0
# 119389                       0                               0
#
#        reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 119387                  D                  D                0   No Deposit
# 119388                  A                  A                0   No Deposit
# 119389                  A                  A                0   No Deposit
#
#         agent  company  days_in_waiting_list customer_type     adr  \
# 119387    9.0      NaN                     0     Transient  157.71
# 119388   89.0      NaN                     0     Transient  104.40
# 119389    9.0      NaN                     0     Transient  151.20
#
#         required_car_parking_spaces  total_of_special_requests  \
# 119387                            0                          4
# 119388                            0                          0
# 119389                            0                          2
#
#        reservation_status reservation_status_date                name  \
# 119387          Check-Out              2017-09-07        Mary Morales
# 119388          Check-Out              2017-09-07  Caroline Conley MD
# 119389          Check-Out              2017-09-07      Ariana Michael
#
#                            email  phone-number       credit_card
# 119387  Mary_Morales@hotmail.com  395-518-4100  ************1821
# 119388   MD_Caroline@comcast.net  531-528-1017  ************7860
# 119389      Ariana_M@xfinity.com  422-804-6403  ************4482
# ------------------------------------------------------------------------
#
#
# 🎲 Visualización de filas aleatorias
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 112775  City Hotel            0          1               2017
# 83063   City Hotel            0         50               2016
# 83403   City Hotel            0          7               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 112775                May                        21
# 83063             January                         3
# 83403             January                         5
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 112775                         26                        0
# 83063                          14                        0
# 83403                          29                        0
#
#         stays_in_week_nights  adults  children  babies meal country  \
# 112775                     2       2       1.0       0   BB     PRT
# 83063                      3       2       0.0       0   BB     FRA
# 83403                      2       2       0.0       0   BB     PRT
#
#        market_segment distribution_channel  is_repeated_guest  \
# 112775         Direct               Direct                  0
# 83063   Offline TA/TO                TA/TO                  0
# 83403   Complementary               Direct                  0
#
#         previous_cancellations  previous_bookings_not_canceled  \
# 112775                       0                               0
# 83063                        0                               0
# 83403                        0                               0
#
#        reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 112775                  B                  B                1   No Deposit
# 83063                   A                  A                0   No Deposit
# 83403                   D                  E                1   No Deposit
#
#         agent  company  days_in_waiting_list customer_type    adr  \
# 112775   14.0      NaN                     0     Transient  179.5
# 83063    20.0      NaN                    43     Transient   52.0
# 83403     NaN     45.0                     0     Transient    0.0
#
#         required_car_parking_spaces  total_of_special_requests  \
# 112775                            0                          0
# 83063                             0                          1
# 83403                             1                          1
#
#        reservation_status reservation_status_date              name  \
# 112775          Check-Out              2017-05-28      Karen Lester
# 83063           Check-Out              2016-01-17  Mr. Antonio Kirk
# 83403           Check-Out              2016-01-31         Erin Rose
#
#                            email  phone-number       credit_card
# 112775  Karen.L99@protonmail.com  494-233-4897  ************4923
# 83063          Kirk.Mr.@zoho.com  194-771-1492  ************3311
# 83403           Erin.R@gmail.com  751-231-0313  ************1401
# ------------------------------------------------------------------------
#
#
# 📏 Dimensión del DataFrame
#
# Número de filas del DataFrame: 119390
# Número de columnas del DataFrame: 36
#
#
# ------------------------------------------------------------------------
#
#
# 🧾 Información general
#
# <class 'pandas.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  str
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  str
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  str
#  13  country                         118902 non-null  str
#  14  market_segment                  119390 non-null  str
#  15  distribution_channel            119390 non-null  str
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  str
#  20  assigned_room_type              119390 non-null  str
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  str
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  str
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  str
#  31  reservation_status_date         119390 non-null  str
#  32  name                            119390 non-null  str
#  33  email                           119390 non-null  str
#  34  phone-number                    119390 non-null  str
#  35  credit_card                     119390 non-null  str
# dtypes: float64(4), int64(16), str(16)
# memory usage: 32.8 MB
#
#
# ------------------------------------------------------------------------
#
#
# ❌ Detección de nulos
#
# El número de valores nulos de cada columna es:
#
# children         4
# country        488
# agent        16340
# company     112593
# dtype: int64
#
# El porcentaje de valores nulos de cada columna es:
#
# children     0.00
# country      0.41
# agent       13.69
# company     94.31
# dtype: float64
#
#
# ------------------------------------------------------------------------
#
#
# 🔁 Detección de duplicados
#
# El número de duplicados del dataset es: 0
#
#
# ------------------------------------------------------------------------
#
#
# 🏷️ Nombres de las columnas
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='str')
# ------------------------------------------------------------------------
#
#
# 🔢 Estadísticas descriptivas de las variables numéricas
#                                    count     mean     std      min      25%  \
# is_canceled                     119390.0     0.37    0.48     0.00     0.00
# lead_time                       119390.0   104.01  106.86     0.00    18.00
# arrival_date_year               119390.0  2016.16    0.71  2015.00  2016.00
# arrival_date_week_number        119390.0    27.17   13.61     1.00    16.00
# arrival_date_day_of_month       119390.0    15.80    8.78     1.00     8.00
# stays_in_weekend_nights         119390.0     0.93    1.00     0.00     0.00
# stays_in_week_nights            119390.0     2.50    1.91     0.00     1.00
# adults                          119390.0     1.86    0.58     0.00     2.00
# children                        119386.0     0.10    0.40     0.00     0.00
# babies                          119390.0     0.01    0.10     0.00     0.00
# is_repeated_guest               119390.0     0.03    0.18     0.00     0.00
# previous_cancellations          119390.0     0.09    0.84     0.00     0.00
# previous_bookings_not_canceled  119390.0     0.14    1.50     0.00     0.00
# booking_changes                 119390.0     0.22    0.65     0.00     0.00
# agent                           103050.0    86.69  110.77     1.00     9.00
# company                           6797.0   189.27  131.66     6.00    62.00
# days_in_waiting_list            119390.0     2.32   17.59     0.00     0.00
# adr                             119390.0   101.83   50.54    -6.38    69.29
# required_car_parking_spaces     119390.0     0.06    0.25     0.00     0.00
# total_of_special_requests       119390.0     0.57    0.79     0.00     0.00
#
#                                     50%     75%     max
# is_canceled                        0.00     1.0     1.0
# lead_time                         69.00   160.0   737.0
# arrival_date_year               2016.00  2017.0  2017.0
# arrival_date_week_number          28.00    38.0    53.0
# arrival_date_day_of_month         16.00    23.0    31.0
# stays_in_weekend_nights            1.00     2.0    19.0
# stays_in_week_nights               2.00     3.0    50.0
# adults                             2.00     2.0    55.0
# children                           0.00     0.0    10.0
# babies                             0.00     0.0    10.0
# is_repeated_guest                  0.00     0.0     1.0
# previous_cancellations             0.00     0.0    26.0
# previous_bookings_not_canceled     0.00     0.0    72.0
# booking_changes                    0.00     0.0    21.0
# agent                             14.00   229.0   535.0
# company                          179.00   270.0   543.0
# days_in_waiting_list               0.00     0.0   391.0
# adr                               94.58   126.0  5400.0
# required_car_parking_spaces        0.00     0.0     8.0
# total_of_special_requests          0.00     1.0     5.0
# ------------------------------------------------------------------------
#
#
# 🔡 Estadísticas descriptivas de las variables categóricas
#                           count  unique                  top    freq
# hotel                    119390       2           City Hotel   79330
# arrival_date_month       119390      12               August   13877
# meal                     119390       5                   BB   92310
# country                  118902     177                  PRT   48590
# market_segment           119390       8            Online TA   56477
# distribution_channel     119390       5                TA/TO   97870
# reserved_room_type       119390      10                    A   85994
# assigned_room_type       119390      12                    A   74053
# deposit_type             119390       3           No Deposit  104641
# customer_type            119390       4            Transient   89613
# reservation_status       119390       3            Check-Out   75166
# reservation_status_date  119390     926           2015-10-21    1461
# name                     119390   81503      Michael Johnson      48
# email                    119390  115889  Michael.C@gmail.com       6
# phone-number             119390  119390         669-792-1661       1
# credit_card              119390    9000     ************3627      28

# %% [markdown]
# ### **Informe de EDA preliminar – Dataset `booking_raw`**
#
# **1. Información general del Dataset**
#
# - El Dataset contiene 119390 registros y +30 variables
#
# - Incluye columnas numéricas, categóricas y temporales.
#
# - Se identifican valores nulos en `agent`, `company`, `country` y `children`.
#
# - No presenta registros duplicados → dataset consistente.
#
# **2. Hallazgos por tipo de variable**
#
# Variables numéricas:
#
# - `adr`: alta variabilidad (hasta 5400), indicando posibles outliers.
# - `lead_time`: media de 104 días, reflejando reservas con bastante anticipación.
# - `is_canceled`: media del 37% → alta tasa de cancelación.
#
# Variables categóricas:
#
# - `adults`, `children`, `babies`: predominan reservas de 1–2 adultos sin niños.
# - `previous_cancellations`: valores bajos → pocos clientes reincidentes cancelando.
# - Predominan clientes “transient” y reservas online.
#
# **3. Transformaciones clave**
#
# Estandarización:
# - `hotel`, `customer_type`, `reservation_status` → minúsculas + snake_case.
# - `phone-number` → `phone_number`.
#
# Tipos de datos:
# - `is_canceled`, `is_repeated_guest` → bool.
# - `reservation_status_date` → datetime.
#
# Eliminación:
# - `name`, `email`, `phone_number`, `credit_card` → indormación del huésped que no es relevante para nuestro análisis.
# - `arrival_date_week_number` → ya disponemos de los días, meses y años de llegada.
#
#
# 💡 **Conclusión:**
#
# El dataset está bien estructurado y, tras limpieza y transformación, queda listo para análisis exploratorio avanzado.

# %% [markdown]
# ---
# ## `reviews_raw`

# %%
# Llamamos a la función eda_preliminar guardada en el archivo de sorporte
eda_preliminar(reviews_raw)
# Out:
# 👀 Visualización de las primeras y últimas filas
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0              Russia    I am so angry that i made this post available...
# 1             Ireland                                         No Negative
# 2           Australia    Rooms are nice but for elderly a bit difficul...
#
#    Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 0                                397                     1403
# 1                                  0                     1403
# 2                                 42                     1403
#
#                                      Positive_Review  \
# 0   Only the park outside of the hotel was beauti...
# 1   No real complaints the hotel was great great ...
# 2   Location was good and staff were ok It is cut...
#
#    Review_Total_Positive_Word_Counts  \
# 0                                 11
# 1                                105
# 2                                 21
#
#    Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 0                                           7             2.9
# 1                                           7             7.5
# 2                                           9             7.1
#
#                                                 Tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 1  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 2  [' Leisure trip ', ' Family with young childre...            3 days
#
#          lat       lng
# 0  52.360576  4.915968
# 1  52.360576  4.915968
# 2  52.360576  4.915968
#                                             Hotel_Address  \
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 515735                           168   8/19/2015            8.1
# 515736                           168   8/17/2015            8.1
# 515737                           168    8/9/2015            8.1
#
#                    Hotel_Name Reviewer_Nationality  \
# 515735  Atlantis Hotel Vienna               Egypt
# 515736  Atlantis Hotel Vienna              Mexico
# 515737  Atlantis Hotel Vienna             Hungary
#
#                                           Negative_Review  \
# 515735   The ac was useless It was a hot week in vienn...
# 515736                                        No Negative
# 515737       I was in 3rd floor It didn t work Free Wife
#
#         Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 515735                                 19                     2823
# 515736                                  0                     2823
# 515737                                 13                     2823
#
#                                           Positive_Review  \
# 515735                                        No Positive
# 515736   The rooms are enormous and really comfortable...
# 515737                               staff was very kind
#
#         Review_Total_Positive_Word_Counts  \
# 515735                                  0
# 515736                                 25
# 515737                                  6
#
#         Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 515735                                           3             2.5
# 515736                                           3             8.8
# 515737                                           1             8.3
#
#                                                      Tags days_since_review  \
# 515735  [' Leisure trip ', ' Family with older childre...           715 day
# 515736  [' Leisure trip ', ' Group ', ' Standard Tripl...           717 day
# 515737  [' Leisure trip ', ' Family with young childre...           725 day
#
#               lat        lng
# 515735  48.203745  16.335677
# 515736  48.203745  16.335677
# 515737  48.203745  16.335677
# ------------------------------------------------------------------------
#
#
# 🎲 Visualización de filas aleatorias
#                                             Hotel_Address  \
# 68826         165 rue de Rome 17th arr 75017 Paris France
# 513729  Wrights Lane Kensington and Chelsea London W8 ...
# 338070  Handelskai 269 02 Leopoldstadt 1020 Vienna Aus...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 68826                             56   9/15/2015            7.6
# 513729                          1172   1/14/2016            7.8
# 338070                           239    1/3/2016            8.4
#
#                              Hotel_Name Reviewer_Nationality  \
# 68826    Best Western Op ra Batignolles      United Kingdom
# 513729    Holiday Inn London Kensington      United Kingdom
# 338070  Hilton Vienna Danube Waterfront           Australia
#
#                                           Negative_Review  \
# 68826                                         No Negative
# 513729   Snacks not available after 10 30pm we went to...
# 338070                                        No Negative
#
#         Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 68826                                   0                      859
# 513729                                 28                     5945
# 338070                                  0                     2349
#
#                                           Positive_Review  \
# 68826    The staff was outstanding he made us feel ver...
# 513729   The convenience and location for buses taxis ...
# 338070   The hotel and staff were great but it was mor...
#
#         Review_Total_Positive_Word_Counts  \
# 68826                                  11
# 513729                                 26
# 338070                                 43
#
#         Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 68826                                            5             9.2
# 513729                                           1            10.0
# 338070                                           1             7.5
#
#                                                      Tags days_since_review  \
# 68826   [' Leisure trip ', ' Couple ', ' Superior Doub...           688 day
# 513729  [' Leisure trip ', ' Group ', ' Standard Doubl...           567 day
# 338070  [' Leisure trip ', ' Couple ', ' King Hilton W...           578 day
#
#               lat        lng
# 68826   48.887057   2.314330
# 513729  51.499981  -0.192879
# 338070  48.214066  16.421763
# ------------------------------------------------------------------------
#
#
# 📏 Dimensión del DataFrame
#
# Número de filas del DataFrame: 515738
# Número de columnas del DataFrame: 17
#
#
# ------------------------------------------------------------------------
#
#
# 🧾 Información general
#
# <class 'pandas.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   Hotel_Address                               515738 non-null  str
#  1   Additional_Number_of_Scoring                515738 non-null  int64
#  2   Review_Date                                 515738 non-null  str
#  3   Average_Score                               515738 non-null  float64
#  4   Hotel_Name                                  515738 non-null  str
#  5   Reviewer_Nationality                        515738 non-null  str
#  6   Negative_Review                             515738 non-null  str
#  7   Review_Total_Negative_Word_Counts           515738 non-null  int64
#  8   Total_Number_of_Reviews                     515738 non-null  int64
#  9   Positive_Review                             515738 non-null  str
#  10  Review_Total_Positive_Word_Counts           515738 non-null  int64
#  11  Total_Number_of_Reviews_Reviewer_Has_Given  515738 non-null  int64
#  12  Reviewer_Score                              515738 non-null  float64
#  13  Tags                                        515738 non-null  str
#  14  days_since_review                           515738 non-null  str
#  15  lat                                         512470 non-null  float64
#  16  lng                                         512470 non-null  float64
# dtypes: float64(4), int64(5), str(8)
# memory usage: 66.9 MB
#
#
# ------------------------------------------------------------------------
#
#
# ❌ Detección de nulos
#
# El número de valores nulos de cada columna es:
#
# lat    3268
# lng    3268
# dtype: int64
#
# El porcentaje de valores nulos de cada columna es:
#
# lat    0.63
# lng    0.63
# dtype: float64
#
#
# ------------------------------------------------------------------------
#
#
# 🔁 Detección de duplicados
#
# El número de duplicados del dataset es: 526
#
#
# ------------------------------------------------------------------------
#
#
# 🏷️ Nombres de las columnas
# Index(['Hotel_Address', 'Additional_Number_of_Scoring', 'Review_Date',
#        'Average_Score', 'Hotel_Name', 'Reviewer_Nationality',
#        'Negative_Review', 'Review_Total_Negative_Word_Counts',
#        'Total_Number_of_Reviews', 'Positive_Review',
#        'Review_Total_Positive_Word_Counts',
#        'Total_Number_of_Reviews_Reviewer_Has_Given', 'Reviewer_Score', 'Tags',
#        'days_since_review', 'lat', 'lng'],
#       dtype='str')
# ------------------------------------------------------------------------
#
#
# 🔢 Estadísticas descriptivas de las variables numéricas
#                                                count     mean      std    min  \
# Additional_Number_of_Scoring                515738.0   498.08   500.54   1.00
# Average_Score                               515738.0     8.40     0.55   5.20
# Review_Total_Negative_Word_Counts           515738.0    18.54    29.69   0.00
# Total_Number_of_Reviews                     515738.0  2743.74  2317.46  43.00
# Review_Total_Positive_Word_Counts           515738.0    17.78    21.80   0.00
# Total_Number_of_Reviews_Reviewer_Has_Given  515738.0     7.17    11.04   1.00
# Reviewer_Score                              515738.0     8.40     1.64   2.50
# lat                                         512470.0    49.44     3.47  41.33
# lng                                         512470.0     2.82     4.58  -0.37
#
#                                                 25%      50%      75%  \
# Additional_Number_of_Scoring                 169.00   341.00   660.00
# Average_Score                                  8.10     8.40     8.80
# Review_Total_Negative_Word_Counts              2.00     9.00    23.00
# Total_Number_of_Reviews                     1161.00  2134.00  3613.00
# Review_Total_Positive_Word_Counts              5.00    11.00    22.00
# Total_Number_of_Reviews_Reviewer_Has_Given     1.00     3.00     8.00
# Reviewer_Score                                 7.50     8.80     9.60
# lat                                           48.21    51.50    51.52
# lng                                           -0.14     0.01     4.83
#
#                                                  max
# Additional_Number_of_Scoring                 2682.00
# Average_Score                                   9.80
# Review_Total_Negative_Word_Counts             408.00
# Total_Number_of_Reviews                     16670.00
# Review_Total_Positive_Word_Counts             395.00
# Total_Number_of_Reviews_Reviewer_Has_Given    355.00
# Reviewer_Score                                 10.00
# lat                                            52.40
# lng                                            16.43
# ------------------------------------------------------------------------
#
#
# 🔡 Estadísticas descriptivas de las variables categóricas
#                        count  unique  \
# Hotel_Address         515738    1493
# Review_Date           515738     731
# Hotel_Name            515738    1492
# Reviewer_Nationality  515738     227
# Negative_Review       515738  330011
# Positive_Review       515738  412601
# Tags                  515738   55242
# days_since_review     515738     731
#
#                                                                     top  \
# Hotel_Address         163 Marsh Wall Docklands Tower Hamlets London ...
# Review_Date                                                    8/2/2017
# Hotel_Name                   Britannia International Hotel Canary Wharf
# Reviewer_Nationality                                    United Kingdom
# Negative_Review                                             No Negative
# Positive_Review                                             No Positive
# Tags                  [' Leisure trip ', ' Couple ', ' Double Room '...
# days_since_review                                                1 days
#
#                         freq
# Hotel_Address           4789
# Review_Date             2585
# Hotel_Name              4789
# Reviewer_Nationality  245246
# Negative_Review       127890
# Positive_Review        35946
# Tags                    5101
# days_since_review       2585

# %% [markdown]
# ### **Informe de EDA preliminar – Dataset `reviews_raw`**
#
# **1. Información general del Dataset**
#
# - El dataset contiene 515738 registros y 17 variables.
#
# - Presenta pocos valores nulos en lat y lng (~0.63%).
#
# - Existen algunos duplicados, pero la estructura general es consistente.
#
# **2. Hallazgos por tipo de variable**
#
# Variables numéricas:
#
# - Reviewer_Score y Average_Score: media ≈ 8.4 → alta satisfacción general.
# - Total_Number_of_Reviews: gran dispersión → diferentes niveles de popularidad.
#
# Variables de texto y categóricas:
#
# - Positive_Review y Negative_Review: alta variabilidad en contenido.
# - Reviewer_Nationality: predominan usuarios del Reino Unido.
#
# **3. Transformaciones clave**
#
# Estandarización:
#
# - Nombres de las columnas → minúsculas + snake_case.
# - reviewer_nationality: “United Kingdom” → “UK”.
# - tags: limpiar caracteres innecesarios.
#
# Tipos de datos:
#
# - review_date → datetime.
# - days_since_review → eliminar la palabra “day” y convertir a int.
#
# Feature engineering:
#
# - hotel_address → crear city y country.
# - Reducir cada review en positive_review y negative_review a una “palabra clave”
#
# Eliminación:
#
# . review_total_negative_word_counts y review_total_positive_word_counts.
# - lat y lng: redundancia+, ya tenemos la localización.
#
# 💡 Conclusión:
#
# El dataset es rico en información y adecuado para análisis de sentimiento. Tras limpieza, estandarización y creación de nuevas variables, queda optimizado para análisis avanzado e integración con bookings.

# %%
reviews_raw['country'] = reviews_raw['Hotel_Address'].apply(lambda x: x.split()[-1])
reviews_raw.sample(5)
# Out:
#                                             Hotel_Address  \
# 294538  Carburton Street Westminster Borough London W1...
# 110606  22 Portman Square Westminster Borough London W...
# 399848  Passeig de Gracia 62 Eixample 08007 Barcelona ...
# 414175  Plaza Carlos Iba ez 3 Sants Montju c 08038 Bar...
# 140316  30 John Islip St Westminster Borough London SW...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 294538                           542    6/2/2017            8.2
# 110606                           597   12/4/2016            7.9
# 399848                           129   2/26/2017            9.2
# 414175                           109   4/16/2017            8.7
# 140316                           807   2/17/2017            8.5
#
#                                      Hotel_Name Reviewer_Nationality  \
# 294538         Holiday Inn London Regent s Park        South Africa
# 110606        Radisson Blu Portman Hotel London              Turkey
# 399848                           Sixtytwo Hotel      United Kingdom
# 414175               Hotel Miramar Barcelona GL      United Kingdom
# 140316  DoubleTree by Hilton London Westminster      Czech Republic
#
#                                           Negative_Review  \
# 294538   Plug in basin didn t operate properly but I s...
# 110606           There was a mice below the lunch buffet
# 399848                                        No Negative
# 414175            Some of the soft furnishings are tired
# 140316                                        No Negative
#
#         Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 294538                                 24                     2266
# 110606                                 10                     2308
# 399848                                  0                     1010
# 414175                                  9                      977
# 140316                                  0                     3269
#
#                                           Positive_Review  \
# 294538   It s in a quieter location than closed to Oxf...
# 110606                                        No Positive
# 399848   Extremely well thought out rooms couldn t bel...
# 414175   The staff were exceptionally friendly everywh...
# 140316   Everything was perfect The staff was friendly...
#
#         Review_Total_Positive_Word_Counts  \
# 294538                                 37
# 110606                                  0
# 399848                                 14
# 414175                                 50
# 140316                                 21
#
#         Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 294538                                           7             9.6
# 110606                                           3             5.0
# 399848                                           2            10.0
# 414175                                           1             7.9
# 140316                                           4            10.0
#
#                                                      Tags days_since_review  \
# 294538  [' Leisure trip ', ' Group ', ' Standard Twin ...           62 days
# 110606  [' Business trip ', ' Solo traveler ', ' Singl...           242 day
# 399848  [' Leisure trip ', ' Couple ', ' Standard Doub...           158 day
# 414175  [' Leisure trip ', ' Family with young childre...           109 day
# 140316  [' Leisure trip ', ' Couple ', ' Queen Room ',...           167 day
#
#               lat       lng  country
# 294538  51.522247 -0.142613  Kingdom
# 110606  51.516191 -0.157949  Kingdom
# 399848  41.393017  2.164615    Spain
# 414175  41.370304  2.171410    Spain
# 140316  51.493236 -0.126908  Kingdom

# %%
reviews_raw['city'] = reviews_raw['Hotel_Address'].apply(lambda x: x.split()[-2])
reviews_raw.sample(5)
# Out:
#                                             Hotel_Address  \
# 295573   Cardenal Reig 11 Les Corts 08028 Barcelona Spain
# 208801  52 Chiswell Street City of London London EC1Y ...
# 467225         Tilling Road London NW2 1LP United Kingdom
# 293959     Capellans 4 Ciutat Vella 08002 Barcelona Spain
# 491133  Via Spallanzani 40 Central Station 20129 Milan...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 295573                           298   8/18/2015            7.7
# 208801                           704    1/7/2017            8.8
# 467225                           269   2/27/2017            7.9
# 293959                           387    6/1/2017            8.9
# 491133                           353   1/24/2017            8.1
#
#                                  Hotel_Name Reviewer_Nationality  \
# 295573          Senator Barcelona Spa Hotel      United Kingdom
# 208801  The Montcalm At Brewery London City              Belize
# 467225       Holiday Inn London Brent Cross      United Kingdom
# 293959             Hotel Barcelona Catedral      United Kingdom
# 491133                      Starhotels Ritz            Slovakia
#
#                                           Negative_Review  \
# 295573   Great for its proximity to the Nou Camp Stadi...
# 208801                                                Nil
# 467225                                        No Negative
# 293959                                        No Negative
# 491133                                        No Negative
#
#         Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 295573                                 31                     3097
# 208801                                  2                     2617
# 467225                                  0                      835
# 293959                                  0                     2695
# 491133                                  0                     4248
#
#                                           Positive_Review  \
# 295573                                        No Positive
# 208801   We got a free upgrade and complementaey wine ...
# 467225   Bed was so comfy and loved the shopping mall ...
# 293959                 Brilliant location Fabulous hotel
# 491133   Fantastic location for shopping staff very he...
#
#         Review_Total_Positive_Word_Counts  \
# 295573                                  0
# 208801                                 17
# 467225                                 31
# 293959                                  6
# 491133                                 23
#
#         Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 295573                                           1            10.0
# 208801                                           4             9.6
# 467225                                           1             9.6
# 293959                                           6            10.0
# 491133                                           4            10.0
#
#                                                      Tags days_since_review  \
# 295573  [' Leisure trip ', ' Couple ', ' King Room ', ...           716 day
# 208801  [' Leisure trip ', ' Couple ', ' Deluxe Double...           208 day
# 467225  [' Leisure trip ', ' Couple ', ' One Bed Featu...           157 day
# 293959  [' Leisure trip ', ' Family with young childre...           63 days
# 491133  [' Leisure trip ', ' Group ', ' Superior Doubl...           191 day
#
#               lat       lng  country       city
# 295573  41.377798  2.113597    Spain  Barcelona
# 208801  51.520815 -0.091532  Kingdom     United
# 467225  51.573106 -0.223333  Kingdom     United
# 293959  41.384829  2.175128    Spain  Barcelona
# 491133  45.477904  9.209497    Italy      Milan
